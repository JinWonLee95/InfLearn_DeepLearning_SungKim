# %%
import tensorflow as tf

import matplotlib
matplotlib.use('TKAgg')
import matplotlib.pyplot as plt

X = [1, 2, 3]
Y = [1, 2, 3]

W = tf.placeholder(tf.float32)

#hypothesis
hypothesis = X*W

#cost function
cost = tf.reduce_mean(tf.square(hypothesis -Y))

#launch graph in a session
sess = tf.Session()

#전역변수 사용
sess.run(tf.global_variables_initializer())

#cost function을 위한 변수들
W_val = []
cost_val = []
for i in range(-30, 50):
    feed_W = i * 0.1
    curr_cost, curr_W = sess.run([cost, W], feed_dict={W: feed_W})
    W_val.append(curr_W)
    cost_val.append(curr_cost)
    
#cost function show
plt.plot(W_val, cost_val)
plt.show()
# Out:
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 0

# %%
import tensorflow as tf
x_data = [1,2,3]
y_data = [1,2,3]

W=tf.Variable(tf.random_normal([1]), name='weight')
X=tf.placeholder(tf.float32)
Y=tf.placeholder(tf.float32)

hypothesis = X*W

cost = tf.reduce_sum(tf.square(hypothesis - Y))

learning_rate = 0.1
gradient = tf.reduce_mean((W * X - Y) * X)
descent = W - learning_rate * gradient
update = W.assign(descent)

sess = tf.Session()

sess.run(tf.global_variables_initializer())

#step cost W 순으로 출력 (W가 1로 가는것을 알 수 있음)
for step in range(21):
    sess.run(update, feed_dict={X: x_data, Y: y_data})
    print(step, sess.run(cost, feed_dict={X: x_data, Y: y_data}), sess.run(W))
# Out:
# 0 0.7674213 [1.2341278]
# 1 0.21828878 [1.1248682]
# 2 0.06209106 [1.0665964]
# 3 0.01766142 [1.035518]
# 4 0.0050237095 [1.018943]
# 5 0.0014289584 [1.0101029]
# 6 0.00040644497 [1.0053881]
# 7 0.000115610834 [1.0028737]
# 8 3.2888343e-05 [1.0015327]
# 9 9.354997e-06 [1.0008174]
# 10 2.6610255e-06 [1.000436]
# 11 7.5651485e-07 [1.0002325]
# 12 2.1518645e-07 [1.000124]
# 13 6.123487e-08 [1.0000662]
# 14 1.7431375e-08 [1.0000353]
# 15 4.966637e-09 [1.0000188]
# 16 1.4038051e-09 [1.00001]
# 17 4.0672887e-10 [1.0000054]
# 18 1.1459633e-10 [1.0000029]
# 19 3.474554e-11 [1.0000015]
# 20 9.166001e-12 [1.0000008]

# %%
import tensorflow as tf

# tf graph input
X = [1,2,3]
Y = [1,2,3]

# set wrong model weights / 원하는 값 대입해서 실험해보면 결국 1.0으로 수렴
W = tf.Variable(-3.0)

#linear model
hypothesis = X*W

#cost/loss function
cost = tf.reduce_mean(tf.square(hypothesis - Y))

# Minimize : Gradient Descent Magic
optimizer = tf.train.GradientDescentOptimizer(learning_rate = 0.1)
train = optimizer.minimize(cost)

sess = tf.Session()
sess.run(tf.global_variables_initializer())

for step in range(100):
    print(step, sess.run(W))
    sess.run(train)
# Out:
# 0 -3.0
# 1 0.7333336
# 2 0.98222226
# 3 0.9988148
# 4 0.99992096
# 5 0.9999947
# 6 0.99999964
# 7 0.99999994
# 8 1.0
# 9 1.0
# 10 1.0
# 11 1.0
# 12 1.0
# 13 1.0
# 14 1.0
# 15 1.0
# 16 1.0
# 17 1.0
# 18 1.0
# 19 1.0
# 20 1.0
# 21 1.0
# 22 1.0
# 23 1.0
# 24 1.0
# 25 1.0
# 26 1.0
# 27 1.0
# 28 1.0
# 29 1.0
# 30 1.0
# 31 1.0
# 32 1.0
# 33 1.0
# 34 1.0
# 35 1.0
# 36 1.0
# 37 1.0
# 38 1.0
# 39 1.0
# 40 1.0
# 41 1.0
# 42 1.0
# 43 1.0
# 44 1.0
# 45 1.0
# 46 1.0
# 47 1.0
# 48 1.0
# 49 1.0
# 50 1.0
# 51 1.0
# 52 1.0
# 53 1.0
# 54 1.0
# 55 1.0
# 56 1.0
# 57 1.0
# 58 1.0
# 59 1.0
# 60 1.0
# 61 1.0
# 62 1.0
# 63 1.0
# 64 1.0
# 65 1.0
# 66 1.0
# 67 1.0
# 68 1.0
# 69 1.0
# 70 1.0
# 71 1.0
# 72 1.0
# 73 1.0
# 74 1.0
# 75 1.0
# 76 1.0
# 77 1.0
# 78 1.0
# 79 1.0
# 80 1.0
# 81 1.0
# 82 1.0
# 83 1.0
# 84 1.0
# 85 1.0
# 86 1.0
# 87 1.0
# 88 1.0
# 89 1.0
# 90 1.0
# 91 1.0
# 92 1.0
# 93 1.0
# 94 1.0
# 95 1.0
# 96 1.0
# 97 1.0
# 98 1.0
# 99 1.0
